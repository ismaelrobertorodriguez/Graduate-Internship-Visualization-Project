# %%
import urllib.request
import json
import pprint
from pprint import pprint
import pandas as pd

# %%
# https://stackoverflow.com/questions/40588852/pandas-read-nested-json
dfUSA = pd.read_csv('data/awardsUSA.csv')

# %%
dfUSA.head()
# Out:
#    Unnamed: 0                                 Company  \
# 0           0                     CU AEROSPACE L.L.C.
# 1           1             Space Lab Technologies, LLC
# 2           2                              UbiQD, Inc
# 3           3  Opterus Research and Development, Inc.
# 4           4                            HINETICS LLC
#
#                                          Award_Title  \
# 0  Scalable and Distributed Inertial Navigation S...
# 1  MarsOasis- An Efficient Autonomously Controlle...
# 2  Tailoring the Solar Spectrum for Enhanced Crop...
# 3  Validated Engineering Tools for Thin-Ply Compo...
# 4  Integrated High Frequency Electric Propulsor f...
#
#                                           Agency Branch     Phase Program  \
# 0  National Aeronautics and Space Administration    NaN  Phase II    STTR
# 1  National Aeronautics and Space Administration    NaN  Phase II    STTR
# 2  National Aeronautics and Space Administration    NaN  Phase II    STTR
# 3  National Aeronautics and Space Administration    NaN  Phase II    STTR
# 4  National Aeronautics and Space Administration    NaN  Phase II    SBIR
#
#   Agency_Tracking_Number       Contract Proposal_Award_Date  ...  \
# 0                 183162  80NSSC20C0020   December 18, 2019  ...
# 1                 182932  80NSSC20C0038   December 20, 2019  ...
# 2                 188052  80NSSC20C0024    January 10, 2020  ...
# 3                 185482  80NSSC20C0025    January 10, 2020  ...
# 4                 188322  80NSSC20C0008   December 18, 2019  ...
#
#                 Contact_Email             PI_Name  PI_Title        PI_Phone  \
# 0     carroll@cuaerospace.com      David Carroll        NaN  (217) 239-1703
# 1      chris@spacelabtech.com  Christine Escobar        NaN  (720) 309-8475
# 2              matt@ubiqd.com    Matthew Bergren        NaN  (505) 310-6766
# 3      tmurphey@opterusrd.com     Thomas Murphey        NaN  (505) 250-3006
# 4  Steven.M.Brockway@nasa.gov          Andy Yoon        NaN  (630) 442-9517
#
#                   PI_Email                                     RI_Name  \
# 0  carroll@cuaerospace.com  University of Illinois at Urbana-Champaign
# 1   chris@spacelabtech.com       Regents of the University of Colorado
# 2           matt@ubiqd.com                       University of Arizona
# 3   tmurphey@opterusrd.com                   COLORADO STATE UNIVERSITY
# 4       ayoon@hinetics.com                                         NaN
#
#    RI_POC_Name RI_POC_Phone Research_Keywords  \
# 0          NaN          NaN               NaN
# 1          NaN          NaN               NaN
# 2          NaN          NaN               NaN
# 3          NaN          NaN               NaN
# 4          NaN          NaN               NaN
#
#                                             Abstract
# 0  Current state of the art inertial measurement ...
# 1  The MarsOasistrade; cultivation system is a ve...
# 2  UbiQD, Inc,nbsp;has partnered with the Univers...
# 3  Opterus Research and Development, Inc. propose...
# 4  We propose the development of a high efficienc...
#
# [5 rows x 40 columns]

# %%
dfUSA['City'] = dfUSA['City'].str.lower()

# %%
dfUSA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27596 entries, 0 to 27595
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               27596 non-null  int64
#  1   Company                                  27596 non-null  object
#  2   Award_Title                              27596 non-null  object
#  3   Agency                                   27596 non-null  object
#  4   Branch                                   16144 non-null  object
#  5   Phase                                    27596 non-null  object
#  6   Program                                  27596 non-null  object
#  7   Agency_Tracking_Number                   27596 non-null  object
#  8   Contract                                 27595 non-null  object
#  9   Proposal_Award_Date                      27072 non-null  object
#  10  Contract_End_Date                        26911 non-null  object
#  11  Solicitation_Number                      22722 non-null  object
#  12  Solicitation_Year                        27596 non-null  int64
#  13  Topic_Code                               27515 non-null  object
#  14  Award_Year                               27596 non-null  int64
#  15  Award_Amount                             27596 non-null  float64
#  16  DUNS                                     27003 non-null  float64
#  17  Hubzone_Owned                            27596 non-null  object
#  18  Socially_and_Economically_Disadvantaged  27596 non-null  object
#  19  Woman_Owned                              27596 non-null  object
#  20  Number_Employees                         19914 non-null  float64
#  21  Company_Website                          9559 non-null   object
#  22  Address1                                 27596 non-null  object
#  23  Address2                                 2089 non-null   object
#  24  City                                     27596 non-null  object
#  25  State                                    27596 non-null  object
#  26  Zip                                      27596 non-null  object
#  27  Contact_Name                             27596 non-null  object
#  28  Contact_Title                            5206 non-null   object
#  29  Contact_Phone                            27582 non-null  object
#  30  Contact_Email                            27595 non-null  object
#  31  PI_Name                                  27596 non-null  object
#  32  PI_Title                                 7738 non-null   object
#  33  PI_Phone                                 27593 non-null  object
#  34  PI_Email                                 27596 non-null  object
#  35  RI_Name                                  3720 non-null   object
#  36  RI_POC_Name                              2363 non-null   object
#  37  RI_POC_Phone                             2092 non-null   object
#  38  Research_Keywords                        13837 non-null  object
#  39  Abstract                                 27587 non-null  object
# dtypes: float64(3), int64(3), object(34)
# memory usage: 8.4+ MB

# %%
dfUSA[(dfUSA['Award_Year'] == 2018)].groupby('RI_Name').Award_Amount.sum().sort_values(ascending=False).head(50)
# Out:
# RI_Name
# UNIVERSITY OF PENNSYLVANIA                                       5639480.00
# WASHINGTON UNIVERSITY                                            5524117.00
# MASSACHUSETTS GENERAL HOSPITAL                                   5485369.00
# DUKE UNIVERSITY                                                  4973839.00
# Southwest Research Institute                                     4449041.00
# University of Utah                                               4293250.00
# BAYLOR COLLEGE OF MEDICINE                                       3961834.00
# UNIVERSITY OF CALIFORNIA, SAN DIEGO                              3634644.00
# Arizona State University                                         3532966.44
# Johns Hopkins University                                         3349153.00
# GEORGIA STATE UNIVERSITY                                         3332902.00
# Woods Hole Oceanographic Institution                             3299840.00
# University of Central Florida                                    3017049.00
# University of Southern California                                3002075.80
# Duke University                                                  2996396.00
# Mississippi State University                                     2849038.00
# UNIV OF NORTH CAROLINA CHAPEL HILL                               2698994.00
# MEDICAL UNIVERSITY OF SOUTH CAROLINA                             2670088.00
# Southern Research                                                2642801.56
# UNIVERSITY OF ARIZONA                                            2514353.00
# University of Maryland                                           2499995.00
# Stanford University                                              2374728.00
# UNIVERSITY OF TX MD ANDERSON CAN CTR                             2177248.00
# Sandia National Laboratories                                     2149822.00
# UNIVERSITY OF TEXAS MED BR GALVESTON                             2128312.00
# CHILDREN&apos;S HOSP OF PHILADELPHIA                             2083993.00
# Ohio State University                                            2067461.00
# National Renewable Energy Laboratory                             2049935.56
# UNIVERSITY OF MICHIGAN                                           2029731.00
# BRIGHAM AND WOMEN&apos;S HOSPITAL                                2001569.00
# Rutgers University                                               2000000.00
# MAYO CLINICJACKSONVILLE                                          2000000.00
# UNIVERSITY OF PITTSBURGH                                         1954978.00
# University of Delaware                                           1924898.00
# Northeastern University                                          1899910.00
# OREGON HEALTH &amp; SCIENCE UNIVERSITY                           1832621.00
# UNIVERSITY OF COLORADO DENVER                                    1821786.00
# Purdue University                                                1799975.00
# Massachusetts Institute of Technology                            1778456.00
# University of Dayton                                             1774428.00
# UNIVERSITY OF MICHIGAN AT ANN ARBOR                              1768235.00
# CLEVELAND CLINIC FOUNDATION                                      1722777.00
# Charles Stark Draper Laboratory                                  1722650.00
# Massachusetts Institute of Tech                                  1624771.00
# RESEARCH FOUNDATION FOR THE STATE UNIVERSITY OF NEW YORK, THE    1623596.00
# Florida State University                                         1599815.00
# Vanderbilt University                                            1534804.00
# GEORGETOWN UNIVERSITY                                            1501256.00
# The University of Chicago                                        1499919.00
# Massachusetts General Hospital                                   1494579.00
# Name: Award_Amount, dtype: float64

# %%
# Out:
# 1011      150000.00
# 1012      131958.75
# 1013      294481.03
# 1014      900000.00
# 1015      199182.00
#             ...
# 27487     149959.00
# 27488     600000.00
# 27489    1744233.00
# 27490    1994205.00
# 27491     994911.00
# Name: Award_Amount, Length: 4669, dtype: float64

# %%
dfUSA[(dfUSA['Zip'] == '02138')].groupby('Agency').Award_Amount.sum().sort_values(ascending=False)
# Out:
# Agency
# Department of Defense                      94525356.44
# National Science Foundation                 4491189.00
# Department of Transportation                2040658.00
# Department of Health and Human Services     1955600.00
# Name: Award_Amount, dtype: float64

# %%
dfUSA[(dfUSA['Zip'] == '')].City
# Out:
# Series([], Name: City, dtype: object)

# %%
dfUSA[(dfUSA['City'] == 'torrance')].groupby('Agency').size().sort_values(ascending=False).head(50)
# Out:
# Agency
# Department of Defense                            406
# Department of Energy                              59
# National Aeronautics and Space Administration     50
# Department of Health and Human Services           15
# Department of Homeland Security                   12
# Department of Agriculture                          9
# Environmental Protection Agency                    4
# Department of Commerce                             4
# Department of Transportation                       3
# dtype: int64

# %%
dfUSA[(dfUSA['State'] == 'CA')].groupby('Agency').size().sort_values(ascending=False).head(50)
# Out:
# Agency
# Department of Defense                            2252
# Department of Health and Human Services          1492
# National Aeronautics and Space Administration     573
# Department of Energy                              538
# National Science Foundation                       504
# Department of Agriculture                          97
# Department of Commerce                             62
# Department of Homeland Security                    44
# Environmental Protection Agency                    28
# Department of Education                            24
# Department of Transportation                       12
# dtype: int64

# %%
dfUSA[(dfUSA['City'] == 'San Diego')].groupby('Agency').size().sort_values(ascending=False).head(50)
# Out:
# Agency
# Department of Defense                            325
# Department of Health and Human Services          261
# National Aeronautics and Space Administration     51
# Department of Energy                              34
# National Science Foundation                       31
# Department of Homeland Security                    8
# Department of Commerce                             4
# Department of Agriculture                          4
# Environmental Protection Agency                    3
# Department of Transportation                       1
# dtype: int64

# %%
dfUSA[(dfUSA['City'] == 'San Diego')].groupby('Company').size().sort_values(ascending=False).head(50)
# Out:
# Company
# ATA Engineering, Inc.                             35
# ENGINEERING AND SOFTWARE SYSTEM SOLUTIONS, INC    32
# SAN DIEGO COMPOSITES, INC.                        32
# Space Micro Inc.                                  27
# Innoflight, Inc.                                  24
# NANOCOMPOSIX INC                                  15
# SURFACE OPTICS CORP.                              15
# 3dt Holdings, LLC                                 14
# NU TREK INC                                       12
# RAM LABORATORIES                                  11
# TREX ENTERPRISES CORPORATION                      11
# ELECTRONIC BIOSCIENCES, INC.                      11
# MAPP BIOPHARMACEUTICAL, INC.                      10
# ABREOS BIOSCIENCES, INC.                           9
# Epigen Biosciences, Inc.                           8
# Spectral Labs Incorporated                         8
# Fuse Integration, Inc.                             8
# Ram Photonics LLC                                  7
# Sensormetrix, INC                                  7
# Far-Tech, Inc.                                     7
# Information Systems Laboratories, Inc.             7
# Sinopia Biosciences, Inc.                          7
# Vivreon Biosciences, LLC                           7
# NanoCellect Biomedical, Inc.                       6
# VALA SCIENCES, INC.                                6
# Objectsecurity LLC                                 6
# Tristan Technologies, Inc.                         6
# EP ANALYTICS, INC..                                6
# Quantum Applied Science And Research, Inc.         6
# PACIFIC SCIENCE AND ENGINEERING GROUP              6
# PREDICTIVE SCIENCE INCORPORATED                    6
# WinSanTor, Inc.                                    6
# ZIVA CORPORATION                                   6
# Peptide Logic LLC                                  6
# Cognionics, Inc.                                   5
# SignalRx Pharmaceuticals Inc.                      5
# Solute                                             5
# ALLELE BIOTECHNOLOGY AND PHARMACEUTICALS           5
# Matrix Sensors, Inc.                               5
# 2W ITECH LLC                                       5
# Arisan Therapeutics, Inc.                          5
# HEAT, LIGHT, AND SOUND RESEARCH, INC.              5
# VLP BIOTECH, INC.                                  5
# Diagnologix, LLC                                   4
# GLOBAL ALGAE INNOVATIONS, INC.                     4
# Groundmetrics, Inc.                                4
# FOMS INC.                                          4
# HI-Z TECHNOLOGY, INC.                              4
# P&amp;J ROBINSON CORP                              4
# Ocean Nano Tech LLC                                4
# dtype: int64

# %%
dfUSA[(dfUSA['City'] == 'Austin')].groupby('Company').size().sort_values(ascending=False).head(50)
# Out:
# Company
# NANOHMICS INC                                      70
# Texas Research Institute, Austin, Inc.             64
# Omega Optics, Inc.                                 22
# ASURAGEN, INC.                                     12
# PAIN THERAPEUTICS, INC.                            11
# Silicon Space Technology Corporation               10
# Applied Nanotech, Inc.                              9
# Systems &amp; Processes Engineering Corporation     9
# Systems &amp; Materials Research Corporation        8
# TEXAS HIGH ENERGY MATERIALS, LLC                    8
# Ascendant Engineering Solutions, LLC                8
# KAI, LLC                                            8
# Crossfield Technology Llc                           7
# STELLARRAY INCORPORATED                             6
# GenXComm, Inc                                       6
# XERIS PHARMACEUTICALS, INC.                         6
# Apptronik, Inc.                                     5
# BIOO SCIENTIFIC CORPORATION                         5
# NANOHYBRIDS INC                                     5
# SILICON AUDIO, LLC                                  5
# applied novel devices                               5
# WINDMILL CARDIOVASCULAR SYSTEMS, INC.               5
# TransWave Photonics, LLC                            4
# Balcones Technologies LLC                           4
# Health Behavior Solutions, Inc.                     3
# Cesiumastro Inc.                                    3
# SPERAGEN, INC.                                      3
# FoVI 3D, Inc.                                       3
# BridgeSource Medical, Corp.                         3
# Paratus Diagnostics                                 3
# Celadyne Technologies, Inc.                         3
# Sandbox Semiconductor Incorporated                  3
# Inview Technology Corporation                       2
# CERTICHEM INC                                       2
# LinkDyn Robotics Inc.                               2
# Hauoli, LLC                                         2
# ImmuDX LLC                                          2
# MATHALICIOUS, LLC                                   2
# Zebra Imaging, Inc.                                 2
# MACROMOLTEK, INC                                    2
# Mu Therapeutics Inc.                                2
# Green Revolution Cooling, Inc.                      2
# Newormics, LLC                                      2
# DILIGENT DROIDS, LLC                                2
# Continuum Analytics, Inc.                           2
# AUSTIN GEOTECH SERVICES INC                         2
# PLASMABILITY, LLC                                   2
# QUERIUM CORP                                        2
# ABSTRACT ENGINEERING LLC                            2
# Electroninks Incorporated                           2
# dtype: int64

# %%
dfUSA[(dfUSA['State'] == 'CA')].groupby('City').size().sort_values(ascending=False).head(50)
# Out:
# City
# san diego              749
# torrance               562
# san francisco          267
# santa barbara          193
# sunnyvale              171
# goleta                 150
# berkeley               150
# los angeles            144
# palo alto              123
# santa monica           112
# irvine                 105
# santa clara             92
# san jose                91
# san mateo               91
# los gatos               89
# mountain view           79
# pasadena                78
# winnetka                75
# carlsbad                62
# menlo park              61
# monrovia                56
# la jolla                49
# hayward                 46
# pleasanton              44
# redwood city            43
# pacoima                 42
# laguna hills            41
# el segundo              40
# oakland                 39
# camarillo               38
# culver city             38
# long beach              38
# westlake village        36
# davis                   36
# riverside               33
# burlingame              33
# emeryville              32
# los altos               32
# sherman oaks            31
# fremont                 30
# san marcos              29
# concord                 29
# encinitas               29
# newark                  28
# santa ana               27
# south san francisco     26
# lake forest             26
# huntington beach        24
# santa cruz              24
# san carlos              24
# dtype: int64

# %%
dfUSA[(dfUSA['State'] == 'TX')].groupby('City').size().sort_values(ascending=False).head(50)
# Out:
# City
# austin             431
# college station    227
# houston            174
# san antonio         83
# dallas              70
# richardson          37
# plano               30
# fort worth          12
# pearland            11
# bryan               10
# galveston           10
# cypress             10
# round rock          10
# sachse               9
# lubbock              7
# arlington            6
# conroe               6
# san marcos           5
# georgetown           5
# stafford             5
# rockwall             5
# mansfield            4
# temple               4
# league city          3
# katy                 3
# keller               3
# friendswood          3
# el paso              3
# hutto                2
# webster              2
# flower mound         2
# itasca               2
# mcdade               2
# leander              2
# cedar park           2
# spring               2
# sugar land           2
# tyler                2
# denton               2
# coppell              1
# colleyville          1
# corinth              1
# desoto               1
# college              1
# buda                 1
# dallad               1
# benbrook             1
# bellaire             1
# dallas               1
# woodlands            1
# dtype: int64

# %%
dfUSA[(dfUSA['State'] == 'MA')].groupby('City').size().sort_values(ascending=False).head(50)
# Out:
# City
# cambridge          524
# woburn             252
# andover            232
# chelmsford         163
# boston             147
# watertown          146
# newton             116
# burlington         104
# bedford             92
# lexington           80
# natick              79
# billerica           54
# waltham             51
# somerville          49
# amherst             46
# worcester           43
# brookline           38
# north billerica     37
# medford             30
# belmont             29
# westford            22
# winchester          22
# sharon              22
# needham             20
# wellesley           19
# marlborough         19
# holliston           18
# framingham          17
# charlton            17
# lowell              14
# sudbury             14
# canton              13
# beverly             13
# weston              12
# walpole             12
# brighton            12
# wilmington          11
# norwood             11
# sturbridge          10
# chestnut hill       10
# acton               10
# auburndale           9
# arlington            9
# barnstable           9
# chelsea              8
# north falmouth       8
# westborough          8
# shrewsbury           8
# concord              8
# hingham              7
# dtype: int64

# %%
dfUSA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27596 entries, 0 to 27595
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               27596 non-null  int64
#  1   Company                                  27596 non-null  object
#  2   Award_Title                              27596 non-null  object
#  3   Agency                                   27596 non-null  object
#  4   Branch                                   16144 non-null  object
#  5   Phase                                    27596 non-null  object
#  6   Program                                  27596 non-null  object
#  7   Agency_Tracking_Number                   27596 non-null  object
#  8   Contract                                 27595 non-null  object
#  9   Proposal_Award_Date                      27072 non-null  object
#  10  Contract_End_Date                        26911 non-null  object
#  11  Solicitation_Number                      22722 non-null  object
#  12  Solicitation_Year                        27596 non-null  int64
#  13  Topic_Code                               27515 non-null  object
#  14  Award_Year                               27596 non-null  int64
#  15  Award_Amount                             27596 non-null  float64
#  16  DUNS                                     27003 non-null  float64
#  17  Hubzone_Owned                            27596 non-null  object
#  18  Socially_and_Economically_Disadvantaged  27596 non-null  object
#  19  Woman_Owned                              27596 non-null  object
#  20  Number_Employees                         19914 non-null  float64
#  21  Company_Website                          9559 non-null   object
#  22  Address1                                 27596 non-null  object
#  23  Address2                                 2089 non-null   object
#  24  City                                     27596 non-null  object
#  25  State                                    27596 non-null  object
#  26  Zip                                      27596 non-null  object
#  27  Contact_Name                             27596 non-null  object
#  28  Contact_Title                            5206 non-null   object
#  29  Contact_Phone                            27582 non-null  object
#  30  Contact_Email                            27595 non-null  object
#  31  PI_Name                                  27596 non-null  object
#  32  PI_Title                                 7738 non-null   object
#  33  PI_Phone                                 27593 non-null  object
#  34  PI_Email                                 27596 non-null  object
#  35  RI_Name                                  3720 non-null   object
#  36  RI_POC_Name                              2363 non-null   object
#  37  RI_POC_Phone                             2092 non-null   object
#  38  Research_Keywords                        13837 non-null  object
#  39  Abstract                                 27587 non-null  object
# dtypes: float64(3), int64(3), object(34)
# memory usage: 8.4+ MB

# %%
dfUSA.groupby('City').size().sort_values(ascending=False).head(50)
# Out:
# City
# san diego          749
# torrance           562
# cambridge          524
# huntsville         463
# austin             431
# rockville          373
# boulder            366
# dayton             305
# ann arbor          292
# san francisco      268
# tucson             261
# hanover            257
# woburn             252
# albuquerque        237
# andover            233
# college station    227
# seattle            209
# durham             197
# new york           197
# santa barbara      193
# salt lake city     189
# roanoke            189
# pittsburgh         184
# houston            174
# sunnyvale          171
# lexington          166
# chelmsford         163
# champaign          159
# charlottesville    151
# goleta             150
# berkeley           150
# baltimore          149
# boston             147
# watertown          146
# arlington          145
# madison            145
# los angeles        144
# atlanta            138
# chapel hill        137
# wheat ridge        135
# orlando            134
# columbus           128
# columbia           125
# palo alto          123
# rockledge          123
# portland           123
# louisville         122
# raleigh            119
# newark             116
# newton             116
# dtype: int64

# %%
dfUSA.groupby('City').size().describe()
# Out:
# count    2230.000000
# mean       12.374888
# std        38.529571
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         7.000000
# max       722.000000
# dtype: float64

# %%
dfUSA[(dfUSA['State'] == 'MA')].groupby('City').size().describe()
# Out:
# count    167.000000
# mean      17.437126
# std       50.798034
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%       10.000000
# max      498.000000
# dtype: float64

# %%
dfUSA[(dfUSA['State'] == 'TX')].groupby('City').size().describe()
# Out:
# count     82.000000
# mean      15.097561
# std       54.118437
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max      409.000000
# dtype: float64

# %%
dfUSA[(dfUSA['State'] == 'CA')].groupby('City').size().describe()
# Out:
# count    379.000000
# mean      14.844327
# std       53.124388
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        8.500000
# max      722.000000
# dtype: float64

# %%
dfUSA[(dfUSA['State'] == 'CA')].groupby('City').Award_Amount.mean().sort_values(ascending=False).head(25)
# Out:
# City
# sebastopol              2.384795e+06
# walnut                  1.984704e+06
# half moon bay           1.833774e+06
# la canada flintridge    1.781090e+06
# fullerton               1.749332e+06
# rohnert park            1.740879e+06
# mountain view,          1.534484e+06
# n. webster              1.500000e+06
# compton                 1.498643e+06
# playa del rey           1.495733e+06
# fallbrook               1.483265e+06
# azusa                   1.250736e+06
# south pasadena          1.151495e+06
# beaverton               9.999995e+05
# hawyard                 9.997925e+05
# alameda,                9.968470e+05
# brea                    9.922800e+05
# emerald hills           9.763245e+05
# piedmont                9.682947e+05
# sacrtamento             9.580778e+05
# aliso viejo             9.417604e+05
# beverly hills           9.215208e+05
# union city              9.070138e+05
# sherman oaks            9.000000e+05
# boulder                 9.000000e+05
# Name: Award_Amount, dtype: float64

# %%
dfUSA[(dfUSA['State'] == 'CA')].groupby('Agency').Award_Amount.mean().sort_values(ascending=False).head(25)
# Out:
# Agency
# Department of Health and Human Services          649177.396126
# Department of Energy                             470914.531859
# Department of Education                          468733.737917
# Department of Defense                            448858.145253
# Department of Homeland Security                  434490.123182
# National Science Foundation                      359417.176587
# Department of Transportation                     341140.672500
# National Aeronautics and Space Administration    331126.207679
# Department of Agriculture                        229331.773196
# Department of Commerce                           216861.326935
# Environmental Protection Agency                  156953.759286
# Name: Award_Amount, dtype: float64

# %%
dfUSA[(dfUSA['Agency'] == 'Department of Energy')].groupby('Zip').Award_Amount.sum().sort_values(ascending=False).head(50)
# Out:
# Zip
# 90404-4021    28935855.42
# 02472-4699    28608985.85
# 44139-1866    16256411.25
# 80303-1379    14828706.00
# 32955-5327    14396439.27
# 01810-1077    13166028.85
# 48906-5061    12550000.00
# 90501-1510    11771469.98
# 80033-1916    11249981.32
# 24501-6953     9830705.48
# 24011-1921     8767929.10
# 90505-5245     8002936.67
# 87505-3914     7931422.92
# 10012-2614     7914351.33
# 80301-2245     7633739.00
# 02466-1311     7548921.00
# 17601-5606     7409677.12
# 37923-4505     7397976.82
# 24136-3645     7110000.00
# 45315-8983     6982920.00
# 80026-8821     6949844.70
# 01507-5238     6784966.36
# 06473-3106     6555775.49
# 73401-0643     6421838.84
# 80304-1146     6065066.55
# 37921-3713     5980000.00
# 61820-7460     5907777.00
# 43035-9423     5907033.00
# 43228-2412     5874981.66
# 94404-1010     5867352.00
# 91331-2210     5612982.00
# 98275-5735     5571448.60
# 01821-3976     5494706.00
# 14624-5101     5493197.00
# 60201-3621     5433774.22
# 12065-8688     5274984.10
# 19804-2410     5264076.00
# 80301-2385     5249998.00
# 60201-5937     5221463.00
# 93101-3407     5185000.00
# 12065-8662     5124987.95
# 29670-1808     4999686.97
# 80303-9672     4951500.00
# 48864-3203     4943861.00
# 96813-4314     4899934.00
# 94538-6410     4819511.00
# 94704-1517     4653255.19
# 03755-3116     4599434.00
# 01803-3304     4574965.00
# 92121          4529830.89
# Name: Award_Amount, dtype: float64

# %%
dfUSA[(dfUSA['State'] == 'CO')].groupby('City').Award_Amount.mean().sort_values(ascending=False).head(50)
# Out:
# City
# frederick            793700.000000
# loveland,            749166.000000
# northglenn           741231.000000
# westminster          738064.622222
# aurora               660711.640000
# englewood            649250.285714
# pine                 568774.000000
# monument             564406.036667
# colorado  springs    562466.500000
# windsor              560643.250000
# buena vista          554850.000000
# centennial           527741.500000
# parker               500999.800000
# golden               498227.000667
# erie                 484623.500000
# boulder              482419.460302
# loveland             467527.600000
# berthoud             446869.375000
# louisville           443859.436207
# colorado springs     438079.294804
# fort collins         434700.641340
# larkspur             432714.863125
# lafayette            413504.565889
# wheat ridge          394422.967778
# broomfield           378005.913043
# littleton            369219.439508
# lakewood             355644.277368
# denver               354495.146667
# longmont             345811.917544
# arvada               340469.600000
# lone tree            329494.600000
# steamboat springs    306758.794615
# lyons                297453.666667
# superior             262979.166667
# wellington           249733.000000
# grand junction       247630.285714
#  broomfield          225000.000000
# bouler               224909.000000
# florissant           224692.000000
# telluride            199384.000000
# boulder              199182.000000
# highlands ranch      176687.333333
# boudler              150000.000000
# greeley              149387.000000
# pinecliffe           124774.000000
# durango              124545.000000
# carbondale           124500.000000
# irvine               123466.000000
# niwot                 87350.000000
# Name: Award_Amount, dtype: float64

# %%
dfMINK.head()
# Out:
#                      Company  \
# 0  Pacific Engineering, Inc.
# 1                NANOVA INC.
# 2     APT THERAPEUTICS, INC.
# 3  J &amp; J Solutions, Inc.
# 4  J &amp; J Solutions, Inc.
#
#                                          Award_Title  \
# 0  Lightweight RSG Launcher Components and AURE C...
# 1  Improved long-term biocompatibility of coronar...
# 2    Human Apyrase Therapy for Acute Ischemic Stroke
# 3  Innovative Device to Improve Safety of Prepari...
# 4  Innovative Device to Improve Safety of Prepari...
#
#                                     Agency                         Branch  \
# 0                    Department of Defense                           Navy
# 1  Department of Health and Human Services  National Institutes of Health
# 2  Department of Health and Human Services                            NaN
# 3  Department of Health and Human Services                            NaN
# 4  Department of Health and Human Services                            NaN
#
#       Phase Program Agency_Tracking_Number           Contract  \
# 0  Phase II    SBIR          N102-144-0885   N00024-12-C-4127
# 1  Phase II    SBIR            R44HL097485  2R44HL097485-04A1
# 2  Phase II    SBIR            SB1NS060175    2SB1NS060175-04
# 3  Phase II    SBIR            R44CA153636    2R44CA153636-04
# 4  Phase II    SBIR            R44CA153636    2R44CA153636-04
#
#   Proposal_Award_Date Contract_End_Date  ...       DUNS  Hubzone_Owned  \
# 0           26-Jan-12         26-Jan-14  ...  177984879              N
# 1           15-May-17         31-Mar-21  ...  800407343              N
# 2            1-Aug-16         31-Jul-19  ...  192266141              N
# 3                 NaN               NaN  ...  827056123              N
# 4           23-Sep-14         31-Aug-17  ...  827056123              N
#
#   Socially_and_Economically_Disadvantaged  Woman_Owned  Number_Employees  \
# 0                                       Y            N               8.0
# 1                                       N            N               NaN
# 2                                       N            N               NaN
# 3                                       N            N               0.0
# 4                                       N            N               NaN
#
#           City State   ZIP5         Zip  \
# 0         Roca    NE  68430       68430
# 1     Columbia    MO  65203  65203-6469
# 2  Saint Louis    MO  63132  63132-2900
# 3    IOWA CITY    IA  52245  52245-6206
# 4    Iowa City    IA  52245  52245-6206
#
#                                             Abstract
# 0  NAVSEA Undersea Defensive Warfare Systems Prog...
# 1  Improved long term biocompatibility of coronar...
# 2  Principal Investigator Program DirectorLastFir...
# 3  ?     DESCRIPTION (provided by applicant): Man...
# 4  DESCRIPTION  provided by applicant   Manual dr...
#
# [5 rows x 25 columns]

# %%
dfMINK.groupby('Agency').count().sort_values('State', ascending=False)
# Out:
#                                                Company  Award_Title  Branch  \
# Agency
# Department of Health and Human Services            365          365     137
# Department of Defense                              213          213     213
# National Science Foundation                        104          104       0
# Department of Agriculture                           75           75       0
# National Aeronautics and Space Administration       48           48       0
# Department of Energy                                46           46       3
# Department of Education                              7            7       3
# Department of Transportation                         6            6       0
# Department of Commerce                               4            4       3
# Department of Homeland Security                      4            4       0
# Environmental Protection Agency                      4            4       0
#
#                                                Phase  Program  \
# Agency
# Department of Health and Human Services          365      365
# Department of Defense                            213      213
# National Science Foundation                      104      104
# Department of Agriculture                         75       75
# National Aeronautics and Space Administration     48       48
# Department of Energy                              46       46
# Department of Education                            7        7
# Department of Transportation                       6        6
# Department of Commerce                             4        4
# Department of Homeland Security                    4        4
# Environmental Protection Agency                    4        4
#
#                                                Agency_Tracking_Number  \
# Agency
# Department of Health and Human Services                           365
# Department of Defense                                             213
# National Science Foundation                                       104
# Department of Agriculture                                          75
# National Aeronautics and Space Administration                      48
# Department of Energy                                               46
# Department of Education                                             7
# Department of Transportation                                        6
# Department of Commerce                                              4
# Department of Homeland Security                                     4
# Environmental Protection Agency                                     4
#
#                                                Contract  Proposal_Award_Date  \
# Agency
# Department of Health and Human Services             365                  224
# Department of Defense                               213                  213
# National Science Foundation                         104                   87
# Department of Agriculture                            67                   45
# National Aeronautics and Space Administration        48                   48
# Department of Energy                                 45                   44
# Department of Education                               6                    6
# Department of Transportation                          6                    6
# Department of Commerce                                4                    4
# Department of Homeland Security                       4                    4
# Environmental Protection Agency                       4                    2
#
#                                                Contract_End_Date  \
# Agency
# Department of Health and Human Services                      225
# Department of Defense                                        180
# National Science Foundation                                   87
# Department of Agriculture                                     37
# National Aeronautics and Space Administration                 48
# Department of Energy                                          41
# Department of Education                                        6
# Department of Transportation                                   6
# Department of Commerce                                         4
# Department of Homeland Security                                4
# Environmental Protection Agency                                2
#
#                                                Solicitation_Number  ...  DUNS  \
# Agency                                                              ...
# Department of Health and Human Services                        344  ...   365
# Department of Defense                                          213  ...   213
# National Science Foundation                                     17  ...   102
# Department of Agriculture                                       16  ...    75
# National Aeronautics and Space Administration                   15  ...    47
# Department of Energy                                            43  ...    46
# Department of Education                                          3  ...     7
# Department of Transportation                                     6  ...     6
# Department of Commerce                                           3  ...     4
# Department of Homeland Security                                  2  ...     4
# Environmental Protection Agency                                  2  ...     4
#
#                                                Hubzone_Owned  \
# Agency
# Department of Health and Human Services                  365
# Department of Defense                                    213
# National Science Foundation                              104
# Department of Agriculture                                 75
# National Aeronautics and Space Administration             48
# Department of Energy                                      46
# Department of Education                                    7
# Department of Transportation                               6
# Department of Commerce                                     4
# Department of Homeland Security                            4
# Environmental Protection Agency                            4
#
#                                                Socially_and_Economically_Disadvantaged  \
# Agency
# Department of Health and Human Services                                            365
# Department of Defense                                                              213
# National Science Foundation                                                        104
# Department of Agriculture                                                           75
# National Aeronautics and Space Administration                                       48
# Department of Energy                                                                46
# Department of Education                                                              7
# Department of Transportation                                                         6
# Department of Commerce                                                               4
# Department of Homeland Security                                                      4
# Environmental Protection Agency                                                      4
#
#                                                Woman_Owned  Number_Employees  \
# Agency
# Department of Health and Human Services                365               130
# Department of Defense                                  213               213
# National Science Foundation                            104               104
# Department of Agriculture                               75                67
# National Aeronautics and Space Administration           48                48
# Department of Energy                                    46                44
# Department of Education                                  7                 2
# Department of Transportation                             6                 1
# Department of Commerce                                   4                 2
# Department of Homeland Security                          4                 4
# Environmental Protection Agency                          4                 2
#
#                                                City  State  ZIP5  Zip  \
# Agency
# Department of Health and Human Services         365    365   365  365
# Department of Defense                           213    213   213  213
# National Science Foundation                     104    104   104  104
# Department of Agriculture                        75     75    75   75
# National Aeronautics and Space Administration    48     48    48   48
# Department of Energy                             46     46    46   46
# Department of Education                           7      7     7    7
# Department of Transportation                      6      6     6    6
# Department of Commerce                            4      4     4    4
# Department of Homeland Security                   4      4     4    4
# Environmental Protection Agency                   4      4     4    4
#
#                                                Abstract
# Agency
# Department of Health and Human Services             365
# Department of Defense                               213
# National Science Foundation                         104
# Department of Agriculture                            75
# National Aeronautics and Space Administration        48
# Department of Energy                                 46
# Department of Education                               7
# Department of Transportation                          6
# Department of Commerce                                4
# Department of Homeland Security                       4
# Environmental Protection Agency                       4
#
# [11 rows x 24 columns]

# %%
dfMINK.groupby('ZIP5').size().sort_values(ascending=False).head(50)
# Out:
# ZIP5
# 63108    85
# 66046    46
# 63132    42
# 52241    40
# 50010    32
# 65401    32
# 66502    31
# 65201    25
# 63006    21
# 68106    21
# 65203    19
# 50014    16
# 52246    14
# 65211    14
# 66047    13
# 50011    12
# 65559    12
# 66103    12
# 52240    11
# 68504    10
# 64742    10
# 63117    10
# 51250    10
# 63101     9
# 68430     9
# 66049     9
# 64110     9
# 66061     9
# 63130     8
# 63124     8
# 63110     8
# 68114     7
# 63105     7
# 63146     7
# 67154     6
# 63104     6
# 52245     6
# 63021     6
# 67260     6
# 68512     5
# 68508     5
# 68502     5
# 52302     5
# 63122     5
# 50266     5
# 63304     4
# 52732     4
# 67401     4
# 52333     4
# 64113     4
# dtype: int64

# %%
dfMINK.groupby('ZIP5').count().sort_values('Company', ascending=False).head(50)

# %%
dfKANS = dfMINK.loc[dfMINK['State']== 'KS']

# %%
dfKANS.groupby('ZIP5').count().sort_values('Company', ascending=False).head(10)
# Out:
#        Company  Award_Title  Agency  Branch  Phase  Program  \
# ZIP5
# 66046       46           46      46      15     46       46
# 66502       31           31      31      10     31       31
# 66047       13           13      13       6     13       13
# 66103       12           12      12       4     12       12
# 66049        9            9       9       2      9        9
# 66061        9            9       9       5      9        9
# 67154        6            6       6       5      6        6
# 67260        6            6       6       6      6        6
# 66503        4            4       4       0      4        4
# 66214        4            4       4       3      4        4
#
#        Agency_Tracking_Number  Contract  Proposal_Award_Date  \
# ZIP5
# 66046                      46        46                   31
# 66502                      31        30                   25
# 66047                      13        13                    9
# 66103                      12        12                    8
# 66049                       9         9                    7
# 66061                       9         9                    8
# 67154                       6         6                    6
# 67260                       6         6                    6
# 66503                       4         4                    3
# 66214                       4         4                    4
#
#        Contract_End_Date  ...  Award_Amount  DUNS  Hubzone_Owned  \
# ZIP5                      ...
# 66046                 28  ...            46    46             46
# 66502                 24  ...            31    31             31
# 66047                  9  ...            13    13             13
# 66103                  8  ...            12    12             12
# 66049                  6  ...             9     9              9
# 66061                  8  ...             9     9              9
# 67154                  5  ...             6     6              6
# 67260                  6  ...             6     6              6
# 66503                  3  ...             4     4              4
# 66214                  4  ...             4     4              4
#
#        Socially_and_Economically_Disadvantaged  Woman_Owned  Number_Employees  \
# ZIP5
# 66046                                       46           46                38
# 66502                                       31           31                30
# 66047                                       13           13                 3
# 66103                                       12           12                 6
# 66049                                        9            9                 8
# 66061                                        9            9                 3
# 67154                                        6            6                 6
# 67260                                        6            6                 6
# 66503                                        4            4                 4
# 66214                                        4            4                 0
#
#        City  State  Zip  Abstract
# ZIP5
# 66046    46     46   46        46
# 66502    31     31   31        31
# 66047    13     13   13        13
# 66103    12     12   12        12
# 66049     9      9    9         9
# 66061     9      9    9         9
# 67154     6      6    6         6
# 67260     6      6    6         6
# 66503     4      4    4         4
# 66214     4      4    4         4
#
# [10 rows x 24 columns]

# %%
dfIOWA = dfMINK.loc[dfMINK['State']== 'IA']
dfIOWA.groupby('ZIP5').count().sort_values('Company', ascending=False).head(10)
# Out:
#        Company  Award_Title  Agency  Branch  Phase  Program  \
# ZIP5
# 52241       40           40      40      13     40       40
# 50010       32           32      32      12     32       32
# 50014       16           16      16       3     16       16
# 52246       14           14      14       8     14       14
# 50011       12           12      12       3     12       12
# 52240       11           11      11       7     11       11
# 51250       10           10      10       0     10       10
# 52245        6            6       6       1      6        6
# 50266        5            5       5       2      5        5
# 52302        5            5       5       5      5        5
#
#        Agency_Tracking_Number  Contract  Proposal_Award_Date  \
# ZIP5
# 52241                      40        40                   28
# 50010                      32        30                   22
# 50014                      16        16                   13
# 52246                      14        14                   10
# 50011                      12        12                   10
# 52240                      11        11                   11
# 51250                      10        10                    1
# 52245                       6         6                    3
# 50266                       5         5                    3
# 52302                       5         5                    5
#
#        Contract_End_Date  ...  Award_Amount  DUNS  Hubzone_Owned  \
# ZIP5                      ...
# 52241                 28  ...            40    40             40
# 50010                 20  ...            32    32             32
# 50014                 13  ...            16    15             16
# 52246                 10  ...            14    14             14
# 50011                 10  ...            12    12             12
# 52240                  9  ...            11    11             11
# 51250                  1  ...            10    10             10
# 52245                  4  ...             6     6              6
# 50266                  3  ...             5     5              5
# 52302                  5  ...             5     5              5
#
#        Socially_and_Economically_Disadvantaged  Woman_Owned  Number_Employees  \
# ZIP5
# 52241                                       40           40                20
# 50010                                       32           32                28
# 50014                                       16           16                13
# 52246                                       14           14                 4
# 50011                                       12           12                 9
# 52240                                       11           11                 7
# 51250                                       10           10                 9
# 52245                                        6            6                 4
# 50266                                        5            5                 3
# 52302                                        5            5                 5
#
#        City  State  Zip  Abstract
# ZIP5
# 52241    40     40   40        40
# 50010    32     32   32        32
# 50014    16     16   16        16
# 52246    14     14   14        14
# 50011    12     12   12        12
# 52240    11     11   11        11
# 51250    10     10   10        10
# 52245     6      6    6         6
# 50266     5      5    5         5
# 52302     5      5    5         5
#
# [10 rows x 24 columns]

# %%
dfMIZZO = dfMINK.loc[dfMINK['State']== 'MO']
dfMIZZO.groupby('ZIP5').count().sort_values('Company', ascending=False).head(10)
# Out:
#        Company  Award_Title  Agency  Branch  Phase  Program  \
# ZIP5
# 63108       85           85      85      37     85       85
# 63132       42           42      42      13     42       42
# 65401       32           32      32      13     32       32
# 65201       25           25      25      19     25       25
# 63006       21           21      21      13     21       21
# 65203       19           19      19       6     19       19
# 65211       14           14      14       6     14       14
# 65559       12           12      12       5     12       12
# 63117       10           10      10       9     10       10
# 64742       10           10      10       1     10       10
#
#        Agency_Tracking_Number  Contract  Proposal_Award_Date  \
# ZIP5
# 63108                      85        85                   61
# 63132                      42        41                   36
# 65401                      32        32                   28
# 65201                      25        25                   23
# 63006                      21        21                   21
# 65203                      19        19                   13
# 65211                      14        14                   11
# 65559                      12        12                   12
# 63117                      10        10                   10
# 64742                      10        10                    7
#
#        Contract_End_Date  ...  Award_Amount  DUNS  Hubzone_Owned  \
# ZIP5                      ...
# 63108                 59  ...            85    85             85
# 63132                 36  ...            42    42             42
# 65401                 24  ...            32    31             32
# 65201                 22  ...            25    25             25
# 63006                 17  ...            21    21             21
# 65203                 12  ...            19    19             19
# 65211                 11  ...            14    14             14
# 65559                 12  ...            12    12             12
# 63117                 10  ...            10    10             10
# 64742                  7  ...            10    10             10
#
#        Socially_and_Economically_Disadvantaged  Woman_Owned  Number_Employees  \
# ZIP5
# 63108                                       85           85                36
# 63132                                       42           42                17
# 65401                                       32           32                30
# 65201                                       25           25                25
# 63006                                       21           21                21
# 65203                                       19           19                16
# 65211                                       14           14                 5
# 65559                                       12           12                12
# 63117                                       10           10                 6
# 64742                                       10           10                 9
#
#        City  State  Zip  Abstract
# ZIP5
# 63108    85     85   85        85
# 63132    42     42   42        42
# 65401    32     32   32        32
# 65201    25     25   25        25
# 63006    21     21   21        21
# 65203    19     19   19        19
# 65211    14     14   14        14
# 65559    12     12   12        12
# 63117    10     10   10        10
# 64742    10     10   10        10
#
# [10 rows x 24 columns]

# %%
dfNEBR = dfMINK.loc[dfMINK['State']== 'NE']
dfNEBR.groupby('ZIP5').count().sort_values('Company', ascending=False).head(10)
# Out:
#        Company  Award_Title  Agency  Branch  Phase  Program  \
# ZIP5
# 68106       21           21      21      18     21       21
# 68504       10           10      10       6     10       10
# 68430        9            9       9       9      9        9
# 68114        7            7       7       4      7        7
# 68512        5            5       5       3      5        5
# 68508        5            5       5       1      5        5
# 68502        5            5       5       0      5        5
# 68521        4            4       4       1      4        4
# 68516        3            3       3       0      3        3
# 68137        3            3       3       1      3        3
#
#        Agency_Tracking_Number  Contract  Proposal_Award_Date  \
# ZIP5
# 68106                      21        21                   21
# 68504                      10        10                    9
# 68430                       9         9                    9
# 68114                       7         7                    6
# 68512                       5         5                    4
# 68508                       5         5                    4
# 68502                       5         5                    5
# 68521                       4         4                    1
# 68516                       3         3                    3
# 68137                       3         3                    1
#
#        Contract_End_Date  ...  Award_Amount  DUNS  Hubzone_Owned  \
# ZIP5                      ...
# 68106                 13  ...            21    21             21
# 68504                  8  ...            10    10             10
# 68430                  8  ...             9     9              9
# 68114                  6  ...             7     7              7
# 68512                  4  ...             5     5              5
# 68508                  4  ...             5     5              5
# 68502                  4  ...             5     5              5
# 68521                  1  ...             4     4              4
# 68516                  2  ...             3     3              3
# 68137                  1  ...             3     3              3
#
#        Socially_and_Economically_Disadvantaged  Woman_Owned  Number_Employees  \
# ZIP5
# 68106                                       21           21                21
# 68504                                       10           10                 6
# 68430                                        9            9                 9
# 68114                                        7            7                 1
# 68512                                        5            5                 1
# 68508                                        5            5                 4
# 68502                                        5            5                 5
# 68521                                        4            4                 4
# 68516                                        3            3                 3
# 68137                                        3            3                 2
#
#        City  State  Zip  Abstract
# ZIP5
# 68106    21     21   21        21
# 68504    10     10   10        10
# 68430     9      9    9         9
# 68114     7      7    7         7
# 68512     5      5    5         5
# 68508     5      5    5         5
# 68502     5      5    5         5
# 68521     4      4    4         4
# 68516     3      3    3         3
# 68137     3      3    3         3
#
# [10 rows x 24 columns]

# %%
dfNEBR.Award_Amount.sum()
# Out:
# 47274016.0

# %%
dfNEBR.groupby('ZIP5').Award_Amount.sum().sort_values(ascending=True).head().plot(kind='barh')

# %%
dfKANS.groupby('ZIP5').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# ZIP5
# 66046    18040517.80
# 66502     8759784.75
# 66103     3991402.00
# 66061     3939185.94
# 66214     3821038.00
# 66047     3558747.00
# 67260     3035170.00
# 66049     2998931.00
# 66044     2698602.00
# 66506     2225828.75
# Name: Award_Amount, dtype: float64

# %%
dfIOWA.groupby('ZIP5').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# ZIP5
# 52241    19845892.00
# 50010    10420428.27
# 52245     8289077.00
# 52246     6061429.00
# 52240     5551451.00
# 51250     5124364.00
# 50014     4921780.32
# 52302     2863971.00
# 50011     2695030.95
# 52242     1987711.00
# Name: Award_Amount, dtype: float64

# %%
dfMIZZO.groupby('ZIP5').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# ZIP5
# 63108    36859721.00
# 63132    23947909.52
# 65201    10953140.04
# 65203     9673893.75
# 65401     9406829.00
# 65211     8441612.00
# 65559     5631684.00
# 63006     5593074.00
# 63117     4841807.00
# 63110     4143426.00
# Name: Award_Amount, dtype: float64

# %%
zip66502 = dfMINK[(dfMINK['ZIP5']== 66502)]
zip66503 = dfMINK[(dfMINK['ZIP5']== 66503)]
zip66506 = dfMINK[(dfMINK['ZIP5']== 66506)]
zipFrame = (zip66502, zip66503, zip66506)
dfKState = pd.concat(zipFrame)

# %%
dfKState.Award_Amount.sum()
# Out:
# 11610533.5

# %%
dfKState.groupby('Agency').size()
# Out:
# Agency
# Department of Agriculture                         6
# Department of Defense                            11
# Department of Energy                              8
# Department of Health and Human Services           3
# National Aeronautics and Space Administration     5
# National Science Foundation                       5
# dtype: int64

# %%
dfKState.groupby('Agency').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# Agency
# Department of Defense                            4581713.75
# Department of Energy                             2027351.75
# Department of Agriculture                        1359392.00
# Department of Health and Human Services          1346933.00
# National Science Foundation                      1250000.00
# National Aeronautics and Space Administration    1045143.00
# Name: Award_Amount, dtype: float64

# %%
dfKANS.groupby('Agency').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# Agency
# Department of Health and Human Services          27925773.00
# Department of Defense                            16066506.49
# Department of Energy                              5378446.55
# National Aeronautics and Space Administration     5281916.00
# Department of Agriculture                         4273168.00
# National Science Foundation                       3094280.00
# Department of Transportation                        98028.24
# Department of Education                             74995.00
# Name: Award_Amount, dtype: float64

# %%
dfMIZZO.groupby('Agency').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# Agency
# Department of Health and Human Services          98030707.52
# Department of Defense                            38946322.55
# National Science Foundation                      12829788.00
# Department of Energy                              8270913.00
# National Aeronautics and Space Administration     7101470.00
# Department of Agriculture                         2419587.00
# Department of Homeland Security                   1649110.00
# Department of Transportation                       281958.75
# Environmental Protection Agency                    273723.76
# Department of Commerce                             120000.00
# Name: Award_Amount, dtype: float64

# %%
dfIOWA.groupby('Agency').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# Agency
# Department of Health and Human Services          47055895.00
# Department of Defense                            11429142.75
# National Science Foundation                       8160222.00
# Department of Agriculture                         5637707.00
# Department of Energy                              3049494.73
# Department of Education                           2299734.06
# National Aeronautics and Space Administration     1098848.00
# Department of Commerce                             300000.00
# Name: Award_Amount, dtype: float64

# %%
dfNEBR.groupby('Agency').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# Agency
# Department of Health and Human Services    23159597.0
# Department of Defense                      14217703.0
# National Science Foundation                 3717843.0
# Department of Agriculture                   2469190.0
# Department of Energy                        1349995.0
# Department of Transportation                1014959.0
# Department of Homeland Security              749996.0
# Department of Commerce                       519733.0
# Department of Education                       75000.0
# Name: Award_Amount, dtype: float64

# %%
dfMINK.groupby('Agency').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# Agency
# Department of Health and Human Services          1.961720e+08
# Department of Defense                            8.065967e+07
# National Science Foundation                      2.780213e+07
# Department of Energy                             1.804885e+07
# Department of Agriculture                        1.479965e+07
# National Aeronautics and Space Administration    1.348223e+07
# Department of Education                          2.449729e+06
# Department of Homeland Security                  2.399106e+06
# Department of Transportation                     1.394946e+06
# Department of Commerce                           9.397330e+05
# Name: Award_Amount, dtype: float64

# %%
dfKANS.groupby('Agency').size().sort_values(ascending=False)
# Out:
# Agency
# Department of Health and Human Services          63
# Department of Defense                            42
# Department of Agriculture                        20
# National Aeronautics and Space Administration    19
# Department of Energy                             15
# National Science Foundation                      12
# Department of Transportation                      1
# Department of Education                           1
# dtype: int64

# %%
dfKANS.groupby('Award_Year').size().sort_values(ascending=False)
# Out:
# Award_Year
# 2018    22
# 2014    21
# 2012    21
# 2019    19
# 2015    19
# 2010    19
# 2013    15
# 2017    14
# 2011    14
# 2016     9
# dtype: int64

# %%
dfKANS[(dfKANS['Award_Year'] == 2018)].groupby('Agency').size().sort_values(ascending=False)
# Out:
# Agency
# Department of Health and Human Services          13
# National Science Foundation                       3
# National Aeronautics and Space Administration     2
# Department of Energy                              2
# Department of Defense                             1
# Department of Agriculture                         1
# dtype: int64

# %%
dfMIZZO[(dfMIZZO['Award_Year'] == 2018)].groupby('Agency').size().sort_values(ascending=False)
# Out:
# Agency
# Department of Health and Human Services          32
# Department of Defense                            11
# National Science Foundation                       4
# National Aeronautics and Space Administration     4
# Department of Agriculture                         4
# Department of Energy                              3
# Department of Transportation                      2
# Department of Commerce                            1
# dtype: int64

# %%
dfIOWA[(dfIOWA['Award_Year'] == 2018)].groupby('Agency').size().sort_values(ascending=False)
# Out:
# Agency
# Department of Health and Human Services    7
# Department of Defense                      6
# Department of Agriculture                  4
# National Science Foundation                3
# Department of Energy                       3
# dtype: int64

# %%
dfNEBR[(dfNEBR['Award_Year'] == 2018)].groupby('Agency').size().sort_values(ascending=False)
# Out:
# Agency
# Department of Health and Human Services    6
# Department of Defense                      1
# dtype: int64

# %%
dfMINK.groupby('Award_Year').size()
# Out:
# Award_Year
# 2010    117
# 2011     73
# 2012     79
# 2013     62
# 2014     85
# 2015     71
# 2016     84
# 2017     92
# 2018    113
# 2019     99
# 2020      1
# dtype: int64

# %%
dfMINK[(dfMINK['Award_Year'] == 2018)].groupby('ZIP5').size().sort_values(ascending=False).head(10)
# Out:
# ZIP5
# 63108    16
# 63132     7
# 65201     6
# 66047     5
# 66061     4
# 65559     4
# 50014     3
# 65203     3
# 50011     3
# 65401     3
# dtype: int64

# %%
dfMINK[(dfMINK['Award_Year'] == 2017)].groupby('ZIP5').size().sort_values(ascending=False).head(10)
# Out:
# ZIP5
# 63108    9
# 52241    7
# 65559    4
# 68430    4
# 63132    4
# 65201    3
# 66502    3
# 65203    2
# 65401    2
# 66046    2
# dtype: int64

# %%
dfMINK[(dfMINK['Award_Year'] == 2016)].groupby('ZIP5').size().sort_values(ascending=False).head(10)
# Out:
# ZIP5
# 63132    12
# 63108     6
# 52241     6
# 50010     4
# 52246     4
# 66046     4
# 65201     3
# 65211     3
# 50011     2
# 63110     2
# dtype: int64

# %%
dfMINK[(dfMINK['Award_Year'] == 2018)].groupby('ZIP5').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# ZIP5
# 63108    6890737.0
# 63132    5164715.0
# 68114    2812787.0
# 65201    2574583.1
# 68512    2279194.0
# 66061    2201637.0
# 52241    2067534.0
# 65559    1581686.0
# 66044    1498797.0
# 63146    1496822.0
# Name: Award_Amount, dtype: float64

# %%
dfKANS[(dfKANS['Award_Year'] == 2018)].groupby('ZIP5').Award_Amount.sum().sort_values(ascending=False).head(10)
# Out:
# ZIP5
# 66061    2201637.0
# 66044    1498797.0
# 66047    1227776.0
# 66212     720181.0
# 66046     349959.0
# 66503     324920.0
# 66103     299931.0
# 67203     299014.0
# 66502     270216.0
# 67010     224094.0
# Name: Award_Amount, dtype: float64

# %%
dfKANS[(dfKANS['Award_Year'] == 2018)].groupby('ZIP5').Award_Amount.sum().sort_values(ascending=False).head()
# Out:
# ZIP5
# 66061    2201637.0
# 66044    1498797.0
# 66047    1227776.0
# 66212     720181.0
# 66046     349959.0
# Name: Award_Amount, dtype: float64

# %%
dfKANS[(dfKANS['Award_Year'] == 2018)].groupby('Agency').Award_Amount.sum().sort_values(ascending=False).head()
# Out:
# Agency
# Department of Health and Human Services          5527155.0
# National Science Foundation                      1170181.0
# Department of Energy                              374048.0
# National Aeronautics and Space Administration     245221.0
# Department of Agriculture                          99920.0
# Name: Award_Amount, dtype: float64
